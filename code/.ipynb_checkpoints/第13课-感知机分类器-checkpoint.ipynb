# %% [markdown]
# ### 本课提纲
# - 什么是分类器
# - 什么是感知机分类器
# - 参数如何训练
# - 练习

# %% [markdown]
# ### 1. 什么是分类器

# %% [markdown]
# 在上一课我们学习过有监督学习，其中有监督学习可以细分为两类具体的算法，一种称之为分类算法，一种称之为回归算法，它们都是要建立一个预测判断模型，模型输入的是特征变量，输出要尽量和目标变量一样。分类的目标变量是离散数字，而回归的目标变量是连续数字。典型的分类应该就是上节课提到的对鸢尾花分类，常见的例子还包括将邮件自动分为垃圾邮件或正常邮件，此时目标变量可以将垃圾邮件的样本编码成1，正常邮件可以编码为0。这种分类算法建立出来的模型我们通常叫做分类器。回归的常见例子如预测某个地区的房价是多少，此时目标变量是金额这种无穷多种可能的连续实数，这种问题称为回归问题。

# %% [markdown]
# # 分类器的图 ch13-01.png

# %% [markdown]
# 下图的最左边图形就是一个典型的分类器，它的表现形式是一条线，将圆点和加号两种类型的样本区分开来，这种能以一条线来表达的分类器称之为线性分类器。中间这个图就复杂一些了，没办法用一条线来完美的划分两类，这种情况只能用弯曲的曲线来划分，最右边的例子也是类似的，只能用一个近似圆形的曲线来划分两类。所以最左边的图我们称之为线性可分，而右边的两个图，我们称之为线性不可分。而感知机算法就是一种能处理线性可分问题的算法。

# %%
from IPython.display import Image
Image(filename='../figures/02_03.png', width=600)

# %% [markdown]
# ### 2. 什么是感知机分类

# %%
Image(filename='../figures/02_01.png', width=500)

# %% [markdown]
# 感知机是最简单的一种人工神经网络，它模仿了大脑的处理机制。想像我们小时候第一次遇到火焰的情况，我们会用手去触摸，此时火焰的高温会通过手上的神经传递到大脑，然后大脑处理这个信息后，会输出警告说，好烫好烫。上图表示了人的神经系统是如何处理信息的。类似的，我们可以用一个数学方法来模仿这种机制，首先是一个输入变量x，代表了外界的信息，然后X输入给某个函数，函数的形式就是很简单的对X的加权求和，W称为权重，b也可以看作是一个和1相乘的权重。当函数计算出大于0的时候，它会输出+1，小于0时输出-1。这些输入的X就好比是我们的手指神经，函数就好比是大脑，输出就好比是做出的判断警告。这些权重一旦确定了，感知机也就确定了。这些权重就是感知机分类器的参数。

# %% [markdown]
# # ch13-02.png

# %% [markdown]
# 让我们把语言描述的意思用公式表达出来，输入 $\displaystyle x$ （实数值向量）映射到输出值 $\displaystyle f(x)$ 上（一个二元的值）。
#
# $$\displaystyle f(x)={\begin{cases}+1&{\text{if }}w\cdot x+b>0\\-1&{\text{else}}\end{cases}}$$

# %% [markdown]
# 下面我们用一个真实的数据例子来看一下，感知机分类器是如何使用的。数据就是上节课遇到过的鸢尾花数据集。

# %%
import pandas as pd

df = pd.read_csv('../data/iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# 这次的数据我们是通过pandas模块，读取本地的一个csv文件获取的。数据的前四列是花的特征，最后一列是花的种类，一共有三个类别。为了简化问题，我们只保留其中的两个类别，这两种类别构成了我们的目标变量Y，然后只用前两列特征变量来构成我们的特征变量X。

# %%
import numpy as np

# 只选择两个种类，把类别字符改为 -1 和 1, 方便画图
y = df.iloc[0:100, 4].values
y = np.where(y == 'Setosa', -1, 1)

# 只选择前两列变量
X = df.iloc[0:100, [0, 2]].values

# %%
X[:5]
# Out:
# array([[5.1, 1.4],
#        [4.9, 1.4],
#        [4.7, 1.3],
#        [4.6, 1.5],
#        [5. , 1.4]])

# %%
y[:5]
# Out:
# array([-1, -1, -1, -1, -1])

# %% [markdown]
# 然后将X进行探索性绘图，因为X正好有两个变量，可以显示在二维平面上，y的类别信息我们用不同的颜色和形状来表示了。

# %%
# 将两个分类先可视化
# %matplotlib inline
import matplotlib.pyplot as plt


plt.scatter(X[:50, 0], X[:50, 1],
            color='red', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1],
            color='blue', marker='x', label='versicolor')

plt.xlabel('petal length [cm]')
plt.ylabel('sepal length [cm]')
plt.legend(loc='upper left')

plt.tight_layout()

# %% [markdown]
# 从图上可以肉眼观察到，这两类花还是比较容易区分的，属于是线性可分的问题。

# %% [markdown]
# 从sklearn模块中加载Perceptron类，然后定义了一个感知机模型对象，定义模型时也同时定义了几个模型的超参数，分别是迭代次数max_iter，学习率eta0。最后使用fit函数来输入数据X和y进行了模型训练，训练模型参数。

# %%
from sklearn.linear_model import Perceptron
ppn = Perceptron(max_iter=40, eta0=0.1, random_state=0)
ppn.fit(X, y)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, eta0=0.1, fit_intercept=True,
#       max_iter=40, n_iter=None, n_jobs=1, penalty=None, random_state=0,
#       shuffle=True, tol=None, verbose=0, warm_start=False)

# %% [markdown]
# 模型训练完毕之后，那些权重W就已经训练完成了，因为本例的特征输入有两个，所以权重也有2个，权重保存在coef中，下面我们来看一下，对于一个新数据，模型是如何预测它是属于哪种花的。

# %%
new_x = np.array([[5.3, 1.2]])

ppn.predict(new_x)

# %%
w1, w2 = ppn.coef_[0]
print("w1:",w1,"\n""w2:",w2)
# Out:
# w1: -0.2499999999999999
# w2: 0.52

# %%
b = ppn.intercept_[0]

# %%
print("b:",b)
# Out:
# b: -0.1

# %% [markdown]
# 可以观察到权重就是 -0.24和0.52，常数是-0.1，下面我们需要画出这条决策边界的画出来，这条线的斜率可以通过下述公式推算出来
#
# $W1*X1 + W2*X2 + b = 0$
#
# $X2 = (-W1/W2)*X1 - b$

# %%
a = -w1/w2

# %%
line_x = np.linspace(4,7,100)
line_y = line_x*a - b

# %%
plt.scatter(X[:50, 0], X[:50, 1],
            color='red', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1],
            color='blue', marker='x', label='versicolor')
plt.plot(line_x,line_y)
plt.xlabel('petal length [cm]')
plt.ylabel('sepal length [cm]')
plt.legend(loc='upper left')

plt.tight_layout()

# %% [markdown]
# ### 3. 参数如何训练出来

# %% [markdown]
# 理解了感知机的基本使用之后，我们来仔细分析一下，这些权重W是如何训练出来的。

# %% [markdown]
# 如果用一句来概括，那些权重W是通过反复试错迭代的思路学习出来的。具体的步骤可以是如下的几个步骤：
#
# 1.先给W一个随机的赋值，
#
# 2.计算给定W下的模型预测值
#
# 3.计算模型预测值和真实目标值之间的差距
#
# 4.根据差距来修正W

# %% [markdown]
# 这个思路整体上和人类的学习是类似的，我们学习拿筷子吃饭的时候，一开始的动作姿势是不正确的，在不正确的姿势下去吃饭，多关会把食物喂到嘴巴外头，这时嘴巴就是我们的真实目标，我们会观察差多少，然后自行修正动作。

# %% [markdown]
# 按照数学上的公式，我们首先定义一些变量来严谨的理解整个思路：
# - $x$ 表示输入变量
# - $w$ 表示权重向量，常数项b也可以认为是一个权重。
# - $f(x)$ 表示神经元接受输入 $x$，根据加权求和然后再通过阶梯函数计算后，产生的模型预测输出
# - $y$ 表示真实的目标值
# - $eta $ 是一个常数，学习率，表示修正的速度。
#
# 感知器的学习通过对**所有训练实例**进行**多次的迭代进行更新**的方式来建模。
#
# 每次迭代权重向量以如下方式修正更新：
# $$ w:= w + (eta * (y-f(x)))*x$$

# %% [markdown]
# 我们仔细来研究这个修正公式 ，如果真实的y和预测值f(x)相等话，它们之间的减法总是等于0，也就是说W和之前一样，不需要修正。只有当它们不一样的时候，才发生修正。如果y等于1，而f(x)输出-1，这种情况意味着$W*X+b$比较小，此时$y-f(x)$等于2，W修正后会比之前大，所以$W*X+b$也会增大，符合此情况下的要求。

# %% [markdown]
# 我们还可以从逻辑图上表示整个修正的步骤，首先我们会用随机值来初始化权重参数W，然后输入一组X，加权求和，再根据感知机的映射函数，计算出预测的目标变量f(x)，再根据f(x)和y之间是否一致，来回头修正权重参数W。

# %%
Image(filename='../figures/02_04.png', width=600)

# %% [markdown]
# 具体的实现代码我们列在下面。

# %%
class Perceptron(object):
    def __init__(self, eta=0.01, n_iter=10):
        self.eta = eta
        self.n_iter = n_iter  

    def net_input(self, X):
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def fit(self, X, y):
        self.w_ = np.random.rand(1 + X.shape[1])  # weights, 初始值0
        self.errors_ = []       
        # 对每个 sample 循环更新
        for _ in range(self.n_iter):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))  #learning rate*error
                self.w_[1:] += update * xi
                self.w_[0] += update
                errors += int(update != 0.0)
            self.errors_.append(errors)  # 错误的分类结果
        return self

    def predict(self, X):
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# %% [markdown]
# Perceptron这个类非常简单，我们分别来介绍这个类中各种方法的功能作用。

# %% [markdown]
# 首先在__init__初始方法中定义了类的两个参数，一个是学习率eta，另一个是n_iter，表示会学习数据多少轮。
# 然后的net_input方法就是一个对输入的X和权重W进行加权求和的过程，这个加权求和就是使用了矩阵计算中的点积来完成，直接使用了numpy模块中的dot函数，权重W的第一个元素是常数项，所以将它单独拿出来做加法。
# 第三个方法fit就是最关键的学习函数，首先是将所有的权重和常数项都用0来定义，同时创建一个列表用来存放error，在每轮迭代的时候，会读取所有的输入数据X和对应的标签Y，然后遍历每条样本，使用权重修正公式来修正W，然后错误的分类结果保存在errors中，整个迭代运行完成之后，W应该学到了正确的值。
# 最后predict方法是用来输出预测值的，也就是映射公式中，大于0就输出1，小于0输出-1.

# %% [markdown]
# 然后我们用自己写的这个类来训练前述的鸢尾花数据。

# %%
ppn = Perceptron(eta=0.1, n_iter=10)
ppn.fit(X, y)
ppn.errors_
# Out:
# [2, 3, 2, 1, 0, 0, 0, 0, 0, 0]

# %% [markdown]
# 类似的可以取出对应的权重参数。

# %%
ppn.w_
# Out:
# array([-0.29454122, -0.74676401,  1.81160274])

# %% [markdown]
# 我们还可以画出图形，观察每个迭代下的模型预测的错误个数。

# %%
# error 画图, 检查是否 error 趋近于0 在多次 loop 更新后
plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of misclassifications')

plt.tight_layout()

# %% [markdown]
# ### 练习

# %% [markdown]
# 使用两种不同的学习率来训练感知机，观察结果

# %%
# 测试两种 learning rate, 0.01 和 0.0001
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))

ppn1 = Perceptron(n_iter=10, eta=0.1).fit(X,y)
ax[0].plot(range(1, len(ppn1.errors_) + 1), np.log10(ppn1.errors_), marker='o')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('log(Sum-squared-error)')
ax[0].set_title('Adaline - Learning rate 0.01')

ppn2 = Perceptron(n_iter=10, eta=0.01).fit(X,y)
ax[1].plot(range(1, len(ppn2.errors_) + 1), ppn2.errors_, marker='o')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Sum-squared-error')
ax[1].set_title('Adaline - Learning rate 0.0001')
# Out:
# /anaconda3/envs/tf3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """
# Text(0.5,1,'Adaline - Learning rate 0.0001')

# %% [markdown]
# ### 本课小结
# - 感知机是一种最基础的机器学习分类算法，它将输入信息通过加权求和的方式汇总起来，再经过一个阶梯函数生成了离散的预测值
# - 感知机的模型参数是加权求和中的那些权重，一开始的权重是随机设置的，通过数据训练来修正这些权重。
# - 权重的修正是为了让模型的预测和真实的目标一致，如果不一致则会进行修正。
# - 感知机在训练中也有一些参数需要人工设置，这些称之为超参数，例如学习率，学习率设置不适合会对训练造成影响。
